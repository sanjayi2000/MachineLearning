# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjayi2000/MachineLearning/blob/main/2348552.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/UK Regional Population Data.csv')

# %%
df
# Out:
#           Code                     Name                  Geography  \
# 0    K02000001           UNITED KINGDOM                    Country
# 1    K03000001            GREAT BRITAIN                    Country
# 2    K04000001        ENGLAND AND WALES                    Country
# 3    E92000001                  ENGLAND                    Country
# 4    E12000001               NORTH EAST                     Region
# ..         ...                      ...                        ...
# 415  N09000006      Fermanagh and Omagh  Local Government District
# 416  N09000007  Lisburn and Castlereagh  Local Government District
# 417  N09000008      Mid and East Antrim  Local Government District
# 418  N09000009               Mid Ulster  Local Government District
# 419  N09000010   Newry, Mourne and Down  Local Government District
#
#      Area (sq km)  Estimated Population mid-2021  2021 people per sq. km  \
# 0     242740.8699                       67026292              276.122814
# ...

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)
df
# Out:
#           Code                     Name                  Geography  \
# 0    K02000001           UNITED KINGDOM                    Country
# 1    K03000001            GREAT BRITAIN                    Country
# 2    K04000001        ENGLAND AND WALES                    Country
# 3    E92000001                  ENGLAND                    Country
# 4    E12000001               NORTH EAST                     Region
# ..         ...                      ...                        ...
# 415  N09000006      Fermanagh and Omagh  Local Government District
# 416  N09000007  Lisburn and Castlereagh  Local Government District
# 417  N09000008      Mid and East Antrim  Local Government District
# 418  N09000009               Mid Ulster  Local Government District
# 419  N09000010   Newry, Mourne and Down  Local Government District
#
#      Area (sq km)  Estimated Population mid-2021  2021 people per sq. km  \
# 0       242740.87                       67026292                  276.12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Code                           420 non-null    object
#  1   Name                           420 non-null    object
#  2   Geography                      420 non-null    object
#  3   Area (sq km)                   420 non-null    float64
#  4   Estimated Population mid-2021  420 non-null    int64
#  5   2021 people per sq. km         420 non-null    float64
#  6   Estimated Population mid-2011  420 non-null    int64
#  7   2011 people per sq. km         420 non-null    float64
#  8   Estimated Population mid-2001  420 non-null    int64
#  9   2001 people per sq. km         420 non-null    float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 32.9+ KB

# %%
df.describe()
# Out:
#        Area (sq km)  Estimated Population mid-2021  2021 people per sq. km  \
# count        420.00                         420.00                  420.00
# mean        3159.19                      989122.26                 1469.10
# std        19377.02                     6096464.99                 2290.77
# min            2.89                        2271.00                    8.72
# 25%          103.88                      108730.50                  193.38
# 50%          338.69                      150760.50                  505.29
# 75%          968.94                      285214.50                 1825.50
# max       242740.87                    67026292.00                15794.50
#
#        Estimated Population mid-2011  2011 people per sq. km  \
# count                         420.00                  420.00
# mean                       932773.75                 1387.30
# std                       5746008.21                 2170.13
# ...

# %%
df.isnull().sum()
# Out:
# Code                             0
# Name                             0
# Geography                        0
# Area (sq km)                     0
# Estimated Population mid-2021    0
# 2021 people per sq. km           0
# Estimated Population mid-2011    0
# 2011 people per sq. km           0
# Estimated Population mid-2001    0
# 2001 people per sq. km           0
# dtype: int64

# %%
df.nunique()
# Out:
# Code                             420
# Name                             420
# Geography                         10
# Area (sq km)                     420
# Estimated Population mid-2021    420
# 2021 people per sq. km           420
# Estimated Population mid-2011    420
# 2011 people per sq. km           420
# Estimated Population mid-2001    420
# 2001 people per sq. km           420
# dtype: int64

# %%
df.sort_values(by="Estimated Population mid-2021", ascending=False).head(10)
# Out:
#           Code               Name Geography  Area (sq km)  \
# 0    K02000001     UNITED KINGDOM   Country     242740.87
# 1    K03000001      GREAT BRITAIN   Country     228947.92
# 2    K04000001  ENGLAND AND WALES   Country     151046.99
# 3    E92000001            ENGLAND   Country     130310.47
# 247  E12000008         SOUTH EAST    Region      19071.85
# 213  E12000007             LONDON    Region       1572.03
# 18   E12000002         NORTH WEST    Region      14108.01
# 162  E12000006               EAST    Region      19115.59
# 127  E12000005      WEST MIDLANDS    Region      12998.27
# 318  E12000009         SOUTH WEST    Region      23835.96
#
#      Estimated Population mid-2021  2021 people per sq. km  \
# 0                         67026292                  276.12
# 1                         65121729                  284.44
# 2                         59641829                  394.86
# 3                         56536419                  433.86
# ...
